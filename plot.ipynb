# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(1,5,11)

# %%
x
# Out:
# array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ])

# %%
y = x ** 2

# %%
y
# Out:
# array([ 1.  ,  1.96,  3.24,  4.84,  6.76,  9.  , 11.56, 14.44, 17.64,
#        21.16, 25.  ])

# %%
plt.plot(x, y, color='red')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Data Contoh')
plt.show()

# %%
# plt dalam 1 subplot
plt.subplot(1, 2, 1)
plt.plot(x, y, 'r--')
plt.subplot(1, 2, 2)
plt.plot(y, x, 'b*-')
plt.show()

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 1, 0.8])
axes.plot(x, y, 'b')
axes.set_xlabel('X axis')
axes.set_ylabel('Y axis')
axes.set_title('Judul')
# Out:
# Text(0.5, 1.0, 'Judul')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes1.plot(x, y, 'b')
axes1.set_xlabel('X Utama')
axes1.set_ylabel('Y Utama')
axes1.set_title('Plot Utama')

axes2.plot(y, x, 'r')
axes2.set_xlabel('X Dalam')
axes2.set_ylabel('Y Dalam')
axes2.set_title('Plot Dalam')
# Out:
# Text(0.5, 1.0, 'Plot Dalam')

# %%
fig = plt.figure(figsize = (8,4), dpi = 100)

# %%
fig, axes = plt.subplots(figsize = (8,3), dpi = 100)

axes.plot(x, x, 'b', label = 'x')
axes.plot(x, x**2, 'r', label = 'x^2')
axes.set_xlabel('X axis')
axes.set_ylabel('Y axis')
axes.set_title('Judul')
axes.legend(loc = 0)

# %%
fig.savefig("contoh.png", dpi = 200)

# %%
fig = plt.figure()

axes = fig.add_axes([0, 0, 1, 1])
axes.plot(x, x+1, color = 'red', linewidth = 0.25)
axes.plot(x, x+2, color = 'red', linewidth = 0.5)
axes.plot(x, x+3, color = 'red', linewidth = 0.75)
axes.plot(x, x+4, color = 'red', linewidth = 1)

# %%
# garis putus2
fig = plt.figure()

axes = fig.add_axes([0, 0, 1, 1])
axes.plot(x, x+1, color = 'green', lw = 3, linestyle = '-')
axes.plot(x, x+2, color = 'green', lw = 3, ls = '-.')
axes.plot(x, x+3, color = 'green', lw = 3, ls = ':')
axes.plot(x, x+4, color = 'green', lw = 3, ls = '--')

# %%
fig = plt.figure()

axes = fig.add_axes([0, 0, 1, 1])
line, = axes.plot(x, x+1, color = 'black', lw = 1.5)
line.set_dashes([5, 5, 15, 5]) #mengatur line style

# %%
fig = plt.figure()

axes = fig.add_axes([0, 0, 1, 1])
line, = axes.plot(x, x+1, color = 'black', marker = '+') #variasi
line, = axes.plot(x, x+2, color = 'red', marker = 'o')
line, = axes.plot(x, x+3, color = 'blue', marker = 's')

# %%
fig = plt.figure()

#Warna
axes = fig.add_axes([0, 0, 1, 1])
line, = axes.plot(x, x+1, color = 'blue', marker = '+', markersize = 10) #variasi
line, = axes.plot(x, x+2, color = 'blue', marker = 'o', markerfacecolor = 'red')
line, = axes.plot(x, x+3, color = 'blue', marker = 's', markerfacecolor = 'yellow', markeredgewidth = 2, markeredgecolor = 'green')

# %%
from random import sample
data = sample(range(1,1000), 10)
plt.hist(data)
# Out:
# (array([2., 0., 1., 3., 2., 0., 0., 0., 1., 1.]),
#  array([147. , 229.4, 311.8, 394.2, 476.6, 559. , 641.4, 723.8, 806.2,
#         888.6, 971. ]),
#  <a list of 10 Patch objects>)

# %%
data
# Out:
# [449, 336, 971, 836, 529, 450, 556, 414, 219, 147]
